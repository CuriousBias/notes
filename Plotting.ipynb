# %%
# writing and reading data from a file

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 100
x = np.linspace(0, 10, n)
y = np.zeros((n, 4))
y[:, 0] = 2*x + 3
y[:, 1] = x**2
y[:, 2] = 10*np.sin(x) + 10
y[:, 3] = 10*np.e**(2*x)

plt.figure(figsize=[10,10])
#plt.plot(x, y)  # simpler way to plot all curves at once
plt.plot(x,y[:,0], 'b-') # this lets you change plotting mark
plt.plot(x,y[:,1], 'ro')
plt.plot(x,y[:,2], 'g+')
plt.plot(x,y[:,3], 'y*')
plt.legend(("2x + 3", "x^2", "10sin(x) + 10","10e^2x"))
plt.xlabel("x")
# plt.semilogx()
plt.ylabel("y")
plt.xlim([0, 10])
plt.ylim([-100, 100])
plt.title("Sample graph of various equations")
plt.show()

# %%
# multi variable and derivatives
fig = plt.figure()
ax = fig.gca(projection='3d')

n = 100
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)

surf = ax.plot_surface(x, y, z)
plt.show()

# %%
# countour plot
fig,ax = plt.subplots(1,1)
contour = ax.contourf(x,y,z)
fig.colorbar(contour)
ax.set_title('Out of plane displacement')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# alternative with in line labels
contour = ax.contour(x,y,z)  # contour NOT contourf
# ax.clabel(contour,inline=True,fontsize=10)

# %%
# more advanced plotting code example
import matplotlib.pyplot as plt
# 3d plot
from mpl_toolkits import mplot3d

plt.figure(1)
plt.subplot(312) # 1st number is rows, 2nd is columns, third is position. 
plt.plot(x, w, x,prob2parallelrad2, x, prob2parallelrad4)
plt.axis([0, 1, 0, 10]) # set axis. note: lack of indent to match line above results in just one plot.     
plt.xlabel('x')
plt.ylabel('Pi')
plt.title('Parallel smoothing functions')
plt.legend(['w','rad = 2 %3.4f seconds' % (parallel2time), 'rad = 4 %3.4f seconds' % (parallel4time)],loc=1)

# for plotting multiple values without saving to arrays
for i in range(Nc):
    y = fwd_euler_parallel(t,y,w,h)
    residual_c[i,:] = y[:, Nt-1, 1] - c[i]*y[:, Nt-1, 0]
    plt.plot(w, residual_c[i,:], label=str(i))
    plt.legend()
plt.xlabel('w [0,10]')
plt.ylabel("y'(pi) - c*y(pi)")
plt.title('Eigenvalues')
plt.show()

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x,y,out, cmap=plt.cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('u')
ax.set_title('Unsteady Heat Conduction')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-909a5ec5ce6a> in <module>
#       6 plt.figure(1)
#       7 plt.subplot(312) # 1st number is rows, 2nd is columns, third is position.
# ----> 8 plt.plot(x, w, x,prob2parallelrad2, x, prob2parallelrad4)
#       9 plt.axis([0, 1, 0, 10]) # set axis. note: lack of indent to match line above results in just one plot.
#      10 plt.xlabel('x')
#
# NameError: name 'w' is not defined
